# %%
#Imports + Seed (same for both runs)
import os, random
import numpy as np
import tensorflow as tf

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %%
#Loading preprocessed MEL images and labels
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import pandas as pd

MEL_DIR = "/content/drive/MyDrive/irmas_multilabel_mels"
LABEL_CSV = "/content/drive/MyDrive/multilabel_labels.csv"

IMG_SIZE = 128

labels_df = pd.read_csv(LABEL_CSV)

X, y = [], []

for _, row in labels_df.iterrows():
    img_path = os.path.join(MEL_DIR, row["file"].replace(".wav", ".png"))
    if not os.path.exists(img_path):
        continue

    img = load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    img = img_to_array(img) / 255.0
    X.append(img)

    y.append(row[1:].values.astype("float32"))

X = np.array(X, dtype=np.float32)
y = np.array(y, dtype=np.float32)

print(X.shape, y.shape)
# Out:
# (1000, 128, 128, 3) (1000, 11)

# %%
#SAME train/val split
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=SEED
)

# %%
#CNN model function (reusable)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_model(learning_rate):
    model = Sequential([
        Conv2D(32, (3,3), activation="relu", input_shape=(128,128,3)),
        MaxPooling2D(2,2),

        Conv2D(64, (3,3), activation="relu"),
        MaxPooling2D(2,2),

        Flatten(),
        Dense(128, activation="relu"),
        Dropout(0.5),
        Dense(y.shape[1], activation="sigmoid")
    ])

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss="binary_crossentropy",
        metrics=["binary_accuracy"]
    )
    return model

# %%
#BASELINE experiment (LR = 0.001)
baseline_model = build_model(learning_rate=0.001)

history_base = baseline_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=32,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - binary_accuracy: 0.7170 - loss: 0.6200 - val_binary_accuracy: 0.7764 - val_loss: 0.5331
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 866ms/step - binary_accuracy: 0.7657 - loss: 0.5620 - val_binary_accuracy: 0.7764 - val_loss: 0.5297
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 951ms/step - binary_accuracy: 0.7682 - loss: 0.5531 - val_binary_accuracy: 0.7764 - val_loss: 0.5215
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 906ms/step - binary_accuracy: 0.7690 - loss: 0.5415 - val_binary_accuracy: 0.7764 - val_loss: 0.5178
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 855ms/step - binary_accuracy: 0.7686 - loss: 0.5354 - val_binary_accuracy: 0.7768 - val_loss: 0.5128
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 858ms/step - binary_accuracy: 0.7674 - loss: 0.5271 - val_binary_accuracy: 0.7773 - val_loss: 0.5089
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 862ms/step - binary_accuracy: 0.7716 - loss: 0.5132 - val_binary_accuracy: 0.7777 - val_loss: 0.5047
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 893ms/step - binary_accuracy: 0.7661 - loss: 0.5085 - val_binary_accuracy: 0.7755 - val_loss: 0.5096
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 886ms/step - binary_accuracy: 0.7711 - loss: 0.5064 - val_binary_accuracy: 0.7773 - val_loss: 0.5040
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 881ms/step - binary_accuracy: 0.7789 - loss: 0.4947 - val_binary_accuracy: 0.7786 - val_loss: 0.5035
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 864ms/step - binary_accuracy: 0.7808 - loss: 0.4796 - val_binary_accuracy: 0.7750 - val_loss: 0.5014
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 916ms/step - binary_accuracy: 0.7906 - loss: 0.4611 - val_binary_accuracy: 0.7777 - val_loss: 0.5064
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 869ms/step - binary_accuracy: 0.7943 - loss: 0.4478 - val_binary_accuracy: 0.7764 - val_loss: 0.5019
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 905ms/step - binary_accuracy: 0.8013 - loss: 0.4347 - val_binary_accuracy: 0.7786 - val_loss: 0.5061
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 906ms/step - binary_accuracy: 0.8086 - loss: 0.4193 - val_binary_accuracy: 0.7814 - val_loss: 0.5065
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 900ms/step - binary_accuracy: 0.8167 - loss: 0.3988 - val_binary_accuracy: 0.7800 - val_loss: 0.5129
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 925ms/step - binary_accuracy: 0.8342 - loss: 0.3732 - val_binary_accuracy: 0.7832 - val_loss: 0.5164
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 913ms/step - binary_accuracy: 0.8279 - loss: 0.3766 - val_binary_accuracy: 0.7841 - val_loss: 0.5165
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 915ms/step - binary_accuracy: 0.8356 - loss: 0.3547 - val_binary_accuracy: 0.7727 - val_loss: 0.5313
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 875ms/step - binary_accuracy: 0.8499 - loss: 0.3370 - val_binary_accuracy: 0.7777 - val_loss: 0.5378

# %%
#Evaluation
from sklearn.metrics import precision_score, recall_score, f1_score

y_pred_base = baseline_model.predict(X_val)
y_pred_base_bin = (y_pred_base >= 0.2).astype(int)

base_precision = precision_score(y_val, y_pred_base_bin, average="micro")
base_recall = recall_score(y_val, y_pred_base_bin, average="micro")
base_f1 = f1_score(y_val, y_pred_base_bin, average="micro")

print("BASELINE")
print("Precision:", base_precision)
print("Recall:", base_recall)
print("F1:", base_f1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 455ms/step
# BASELINE
# Precision: 0.328125
# Recall: 0.5548780487804879
# F1: 0.4123867069486405

# %%
#MODIFIED experiment (LR = 0.0001)
modified_model = build_model(learning_rate=0.0001)

history_mod = modified_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=32,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 875ms/step - binary_accuracy: 0.6921 - loss: 0.6125 - val_binary_accuracy: 0.7764 - val_loss: 0.5405
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 926ms/step - binary_accuracy: 0.7535 - loss: 0.5682 - val_binary_accuracy: 0.7764 - val_loss: 0.5327
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 849ms/step - binary_accuracy: 0.7486 - loss: 0.5754 - val_binary_accuracy: 0.7764 - val_loss: 0.5305
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 993ms/step - binary_accuracy: 0.7552 - loss: 0.5648 - val_binary_accuracy: 0.7764 - val_loss: 0.5269
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 858ms/step - binary_accuracy: 0.7524 - loss: 0.5567 - val_binary_accuracy: 0.7764 - val_loss: 0.5268
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 924ms/step - binary_accuracy: 0.7572 - loss: 0.5545 - val_binary_accuracy: 0.7764 - val_loss: 0.5242
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 933ms/step - binary_accuracy: 0.7601 - loss: 0.5517 - val_binary_accuracy: 0.7764 - val_loss: 0.5207
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 887ms/step - binary_accuracy: 0.7582 - loss: 0.5422 - val_binary_accuracy: 0.7764 - val_loss: 0.5183
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 859ms/step - binary_accuracy: 0.7572 - loss: 0.5430 - val_binary_accuracy: 0.7764 - val_loss: 0.5175
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 899ms/step - binary_accuracy: 0.7549 - loss: 0.5425 - val_binary_accuracy: 0.7764 - val_loss: 0.5171
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 910ms/step - binary_accuracy: 0.7623 - loss: 0.5331 - val_binary_accuracy: 0.7773 - val_loss: 0.5160
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 914ms/step - binary_accuracy: 0.7657 - loss: 0.5304 - val_binary_accuracy: 0.7773 - val_loss: 0.5134
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 898ms/step - binary_accuracy: 0.7649 - loss: 0.5244 - val_binary_accuracy: 0.7768 - val_loss: 0.5097
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 938ms/step - binary_accuracy: 0.7630 - loss: 0.5207 - val_binary_accuracy: 0.7768 - val_loss: 0.5063
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 875ms/step - binary_accuracy: 0.7694 - loss: 0.5122 - val_binary_accuracy: 0.7773 - val_loss: 0.5068
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 974ms/step - binary_accuracy: 0.7688 - loss: 0.5100 - val_binary_accuracy: 0.7777 - val_loss: 0.5025
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 876ms/step - binary_accuracy: 0.7731 - loss: 0.5058 - val_binary_accuracy: 0.7786 - val_loss: 0.5038
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 870ms/step - binary_accuracy: 0.7722 - loss: 0.5014 - val_binary_accuracy: 0.7782 - val_loss: 0.5041
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 944ms/step - binary_accuracy: 0.7757 - loss: 0.4929 - val_binary_accuracy: 0.7773 - val_loss: 0.4991
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 946ms/step - binary_accuracy: 0.7753 - loss: 0.4962 - val_binary_accuracy: 0.7773 - val_loss: 0.5022

# %%
#Evaluate
y_pred_mod = modified_model.predict(X_val)
y_pred_mod_bin = (y_pred_mod >= 0.2).astype(int)

mod_precision = precision_score(y_val, y_pred_mod_bin, average="micro")
mod_recall = recall_score(y_val, y_pred_mod_bin, average="micro")
mod_f1 = f1_score(y_val, y_pred_mod_bin, average="micro")

print("MODIFIED")
print("Precision:", mod_precision)
print("Recall:", mod_recall)
print("F1:", mod_f1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# MODIFIED
# Precision: 0.2757452574525745
# Recall: 0.8272357723577236
# F1: 0.4136178861788618

# %%
#Final Comparison
print("\n===== COMPARISON =====")
print(f"Baseline LR=0.001 → F1: {base_f1:.4f}")
print(f"Modified LR=0.0001 → F1: {mod_f1:.4f}")

if mod_f1 > base_f1:
    print("Lower learning rate IMPROVED multilabel performance")
else:
    print("Lower learning rate did NOT improve performance")
# Out:
# ===== COMPARISON =====
# Baseline LR=0.001 → F1: 0.4124
# Modified LR=0.0001 → F1: 0.4136
# Lower learning rate IMPROVED multilabel performance
