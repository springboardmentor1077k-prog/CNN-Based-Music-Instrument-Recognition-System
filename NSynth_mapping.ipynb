# %%
# !pip install datasets torchcodec librosa soundfile
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 47.3 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("mteb/nsynth-mini")
dataset
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/293M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/298M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/300M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/3002 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
# ...

# %%
#printing metadata entries
print("----- Metadata Entry 1 -----")
print(dataset['train'][0])

print("\n----- Metadata Entry 2 -----")
print(dataset['train'][1])

print("\n----- Metadata Entry 3 -----")
print(dataset['train'][2])
# Out:
# ----- Metadata Entry 1 -----
# {'audio': <datasets.features._torchcodec.AudioDecoder object at 0x79b4e97d6330>, 'note': 180871, 'sample_rate': 16000, 'pitch': 81, 'instrument_source': 0, 'instrument_family_str': 'mallet', 'instrument_str': 'mallet_acoustic_065', 'note_str': 'mallet_acoustic_065-081-127', 'qualities_str': ['fast_decay', 'percussive'], 'instrument_source_str': 'acoustic', 'velocity': 127, 'instrument_family': 5, 'instrument': 676, 'qualities': [0, 0, 0, 1, 0, 0, 0, 1, 0, 0]}
#
# ----- Metadata Entry 2 -----
# ...

# %%
import librosa

# Load first 3 audios
for i in range(3):
    audio_array = dataset['train'][i]['audio']['array']
    sr = dataset['train'][i]['audio']['sampling_rate']
    print(f"\nAudio {i+1} Loaded — shape: {audio_array.shape}, SR: {sr}")
# Out:
# Audio 1 Loaded — shape: (64000,), SR: 16000
#
# Audio 2 Loaded — shape: (64000,), SR: 16000
#
# Audio 3 Loaded — shape: (64000,), SR: 16000

# %%
train_ds = dataset["train"]
train_ds.features
# Out:
# {'audio': Audio(sampling_rate=None, decode=True, stream_index=None),
#  'note': Value('int64'),
#  'sample_rate': Value('int64'),
#  'pitch': Value('int64'),
#  'instrument_source': Value('int64'),
#  'instrument_family_str': Value('string'),
#  'instrument_str': Value('string'),
#  'note_str': Value('string'),
#  'qualities_str': List(Value('string')),
#  'instrument_source_str': Value('string'),
#  'velocity': Value('int64'),
#  'instrument_family': Value('int64'),
#  'instrument': Value('int64'),
#  'qualities': List(Value('int64'))}

# %%
instrument_family_labels = [
    "bass",
    "brass",
    "flute",
    "guitar",
    "keyboard",
    "mallet",
    "organ",
    "reed",
    "string",
    "synth_lead",
    "vocal"
]

# %%
instrument_source_labels = [
    "acoustic",
    "electronic",
    "synthetic"
]

# %%
print("Instrument families:")
print(instrument_family_labels)

print("\nInstrument sources:")
print(instrument_source_labels)
# Out:
# Instrument families:
# ['bass', 'brass', 'flute', 'guitar', 'keyboard', 'mallet', 'organ', 'reed', 'string', 'synth_lead', 'vocal']
#
# Instrument sources:
# ['acoustic', 'electronic', 'synthetic']

# %%
import pandas as pd

mapping = []

train_ds = dataset["train"]  # select train split

for i in range(10):
    sample = train_ds[i]

    mapping.append({
        "file_name": f"sample_{i}.wav",
        "instrument_family": instrument_family_labels[sample["instrument_family"]],
        "instrument_source": instrument_source_labels[sample["instrument_source"]]
    })

df = pd.DataFrame(mapping)
df
# Out:
#       file_name instrument_family instrument_source
# 0  sample_0.wav            mallet          acoustic
# 1  sample_1.wav            mallet        electronic
# 2  sample_2.wav             flute         synthetic
# 3  sample_3.wav              bass         synthetic
# 4  sample_4.wav            string          acoustic
# 5  sample_5.wav          keyboard        electronic
# 6  sample_6.wav              bass         synthetic
# 7  sample_7.wav          keyboard        electronic
# 8  sample_8.wav              bass         synthetic
# 9  sample_9.wav             organ        electronic
